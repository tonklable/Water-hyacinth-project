# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

img = cv.imread('./1x/Asset 2.png',cv.IMREAD_GRAYSCALE)
img=(img-121)//(138-121)
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        if img[i,j]==7:
            img[i,j]=16
plt.hist(img[:,:].ravel(),255,[1,15],color='red')
plt.figure(figsize=(20,16),dpi=100)
plt.imshow(img, cmap="gray")
plt.grid(False)
print(img[:,:].ravel())
print(-10//5)
unique, counts = np.unique(img, return_counts=True)
a=dict(zip(unique, counts))
b=a[10]+a[11]+a[12]+a[13]+a[14]+a[15]
print(a)
print(img.shape[0]*img.shape[1]-a[16],b)
# Out:
# [16 16 16 ... 16 16 16]
# -2
# {0: 50204, 1: 95738, 2: 148782, 3: 182839, 4: 2544, 5: 1490, 6: 1515, 8: 149, 9: 389, 10: 784, 11: 3089, 12: 8755, 13: 21526, 14: 34142, 15: 2200, 16: 2484672}
# 554146 70496

# %%
#Calculate percentage of 
r=img.shape[0]*img.shape[1]-a[16]
print("{0}{1}".format(b*100//r,"%"))
# Out:
# 12%

# %%
"{}sodfj".format(2)
# Out:
# '2sodfj'
